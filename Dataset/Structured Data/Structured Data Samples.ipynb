# %%
import pandas as pd
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load datasets
survey_df = pd.read_csv("/content/drive/MyDrive/Structured Data Files/Cleaned_Survey.csv")
twitter_df = pd.read_csv("/content/drive/MyDrive/Structured Data Files/Cleaned_Twitter.csv")
tripadvisor_df = pd.read_csv("/content/drive/MyDrive/Structured Data Files/Cleaned_TripAdvisor.csv")
booking_df = pd.read_csv("/content/drive/MyDrive/Structured Data Files/Cleaned_Booking.csv")
#Ministry of Tourism data sheets
KeyIndic_df = pd.read_csv("/content/drive/MyDrive/Structured Data Files/Cleaned_Tourism_Key_Indicators.csv")
MainPurpose_df = pd.read_csv("/content/drive/MyDrive/Structured Data Files/Cleaned_Tourists_Number_Main_Purpose.csv")
TouristNumProv_df = pd.read_csv("/content/drive/MyDrive/Structured Data Files/Cleaned_Tourists_Number_Provinces.csv")

# %% [markdown]
# # Survey Sample

# %%
print('First 10 rows:')
survey_df.head(10)
# Out:
# First 10 rows:
#                  timestamp  \
# 0  2025-02-06 16:14:53.594
# 1  2025-02-06 16:19:59.195
# 2  2025-02-06 16:21:46.676
# 3  2025-02-06 16:26:14.395
# 4  2025-02-06 16:27:50.655
# 5  2025-02-06 16:29:04.953
# 6  2025-02-06 16:29:12.680
# 7  2025-02-06 16:34:52.582
# 8  2025-02-06 16:35:11.593
# 9  2025-02-06 16:41:20.095
#
#   0-which_city_or_destination_in_saudi_arabia_did_you_visit_the_most?  \
# 0                                              شقراء
# 1                                             Dammam
# 2                                             Riyadh
# 3                                             Riyadh
# 4                                             Riyadh
# 5                                             Riyadh
# 6                                             Jeddah
# 7                                             Riyadh
# 8                                             Al-Ula
# 9                                             Riyadh
#
# ...

# %%
print('Last 10 rows:')
survey_df.tail(10)
# Out:
# Last 10 rows:
#                   timestamp  \
# 49  2025-02-06 19:07:21.696
# 50  2025-02-06 19:41:12.268
# 51  2025-02-06 19:59:10.362
# 52  2025-02-06 21:33:24.201
# 53  2025-02-07 01:32:53.966
# 54  2025-02-07 05:49:51.720
# 55  2025-02-07 11:41:08.410
# 56  2025-02-08 04:19:04.515
# 57  2025-02-08 04:22:32.921
# 58  2025-03-09 18:49:12.267
#
#    0-which_city_or_destination_in_saudi_arabia_did_you_visit_the_most?  \
# 49                                   Eastern Province
# 50                                             Riyadh
# 51                                             Riyadh
# 52                                             Riyadh
# 53                                             Jeddah
# 54                                             Riyadh
# 55  Al-Taif (almost all my trips were there i am s...
# 56                                             Jeddah
# 57                                             Riyadh
# 58                                             Jeddah
#
# ...

# %%
print('Random 10 rows:')
survey_df.sample(10)
# Out:
# Random 10 rows:
#                   timestamp  \
# 14  2025-02-06 16:53:00.713
# 8   2025-02-06 16:35:11.593
# 39  2025-02-06 18:24:11.384
# 6   2025-02-06 16:29:12.680
# 0   2025-02-06 16:14:53.594
# 21  2025-02-06 17:28:40.561
# 12  2025-02-06 16:46:34.468
# 31  2025-02-06 18:16:58.075
# 56  2025-02-08 04:19:04.515
# 54  2025-02-07 05:49:51.720
#
#    0-which_city_or_destination_in_saudi_arabia_did_you_visit_the_most?  \
# 14                                             Al-Ula
# 8                                              Al-Ula
# 39                                             Riyadh
# 6                                              Jeddah
# 0                                               شقراء
# 21                                             Riyadh
# 12                                             Riyadh
# 31                                              Ha'il
# 56                                             Jeddah
# 54                                             Riyadh
#
# ...

# %% [markdown]
# # X Sample

# %%
print('First 10 rows:')
twitter_df.head(10)
# Out:
# First 10 rows:
#                    timestamp  \
# 0  2025-01-29 11:57:32+00:00
# 1  2025-01-29 11:52:51+00:00
# 2  2025-01-29 10:37:06+00:00
# 3  2025-01-29 09:58:28+00:00
# 4  2025-01-29 06:19:16+00:00
# 5  2025-01-28 18:30:10+00:00
# 6  2025-01-28 16:46:41+00:00
# 7  2025-01-28 14:03:03+00:00
# 8  2025-01-28 12:54:09+00:00
# 9  2025-01-28 09:27:35+00:00
#
#                                              content
# 0  from the moment you arrive at tulip inn al dar...
# 1  a view of the prophets mosque a refreshing win...
# 2  at yella schoff were redefining travel across ...
# 3  saudiarabias tourism marketsize witnesses rapi...
# 4                      \n\n cpjeddah\n ksa saudia...
# 5  when was the last time you did something for t...
# 6  witness the adrenalinepumping hail internation...
# 7  travel agents in uk amp europe\n\ndiscover sau...
# 8  visitsaudi ksa tourism abha travel thislandisc...
# 9  new hotel opening in saudi gt desert rock  the...

# %%
print('Last 10 rows:')
twitter_df.tail(10)
# Out:
# Last 10 rows:
#                     timestamp  \
# 43  2025-01-23 11:40:00+00:00
# 44  2025-01-23 09:40:00+00:00
# 45  2025-01-23 09:02:43+00:00
# 46  2025-01-23 07:23:25+00:00
# 47  2025-01-23 06:38:17+00:00
# 48  2025-01-22 22:00:00+00:00
# 49  2025-01-22 18:07:17+00:00
# 50  2025-01-22 18:00:00+00:00
# 51  2025-01-22 16:30:25+00:00
# 52  2025-01-22 14:30:08+00:00
#
#                                               content
# 43            \n\n  \nsaudiwinter visitsaudi thisl...
# 44                   \n\n  \nsaudiwinter visitsaud...
# 45  visiting riyadh the new riyadh metro is a grea...
# 46             \nvisitsaudiar \nvisitsaudi\n\n \ns...
# 47        \n   \nsamaterps samaterp    visitsaudi ...
# 48          \n\n  \nsaudiwinter visitsaudi thislan...
# 49                 \n\nriyadh  tourism  \nvisitsaudi
# 50             \nvisitsaudiar visitsaudi\n \nsaudi...
# 51  calling all thrillseekers  saudiredsea is your...
# 52  when was the last time you did something for t...

# %%
print('Random 10 rows:')
twitter_df.sample(10)
# Out:
# Random 10 rows:
#                     timestamp  \
# 19  2025-01-26 10:57:36+00:00
# 6   2025-01-28 16:46:41+00:00
# 2   2025-01-29 10:37:06+00:00
# 10  2025-01-28 06:35:28+00:00
# 50  2025-01-22 18:00:00+00:00
# 9   2025-01-28 09:27:35+00:00
# 5   2025-01-28 18:30:10+00:00
# 24  2025-01-25 03:09:03+00:00
# 52  2025-01-22 14:30:08+00:00
# 47  2025-01-23 06:38:17+00:00
#
#                                               content
# 19  when was the last time you did something for t...
# 6   witness the adrenalinepumping hail internation...
# 2   at yella schoff were redefining travel across ...
# 10           \n\ncrowneplazajeddah cpjeddah jeddah...
# 50             \nvisitsaudiar visitsaudi\n \nsaudi...
# 9   new hotel opening in saudi gt desert rock  the...
# 5   when was the last time you did something for t...
# 24  the southern approach at shebara by redseaglob...
# 52  when was the last time you did something for t...
# 47        \n   \nsamaterps samaterp    visitsaudi ...

# %% [markdown]
# # TripAdvisor Sample

# %%
print('First 10 rows:')
tripadvisor_df.head(10)
# Out:
# First 10 rows:
#                                              address addressobj/city  \
# 0  Ibrahim Al Khalil Rd Masfelah District, Mecca ...           Mecca
# 1  8792 Al Rayan Unit No. 1 Imam Boukhari Street,...        Buraidah
# 2  Al Urubah Rd Umm Al Hamam Al Gharbi, Riyadh 12...          Riyadh
# 3  Muhammad Zaidan, Al Naeem, Jeddah, Jeddah 2352...          Jeddah
# 4  Al Dalaa Northern 1244 Bldg No 8964, NEOM Comm...         Sharmaa
# 5  Corniche Road Al Shatiea, Jeddah 21411 Saudi A...          Jeddah
# 6           North Hail City Road, Ha'il Saudi Arabia           Ha'il
# 7          King Fahd Road, Dammam 31441 Saudi Arabia          Dammam
# 8  Jarir Street Al Ihsa Interchange, Riyadh 12831...          Riyadh
# 9  Prince Turkey Street 6681 Al Amir Turki, Unit ...       Al Khobar
#
#   addressobj/country addressobj/postalcode  \
# 0       Saudi Arabia                 24231
# 1       Saudi Arabia                 52344
# 2       Saudi Arabia                 12328
# ...

# %%
print('Last 10 rows:')
tripadvisor_df.tail(10)
# Out:
# Last 10 rows:
#                                                 address addressobj/city  \
# 1646  Al Balad-Madinah Road, Al Jubail 35514 Saudi A...       Al Jubail
# 1647  Al Dawadmi Street, Al Mughrizat District, Riya...          Riyadh
# 1648  Abu Ayyub Al Ansari, Central Area, Medina 4231...          Medina
# 1649  Al Hijra Street Al Missfallah District, Mecca ...           Mecca
# 1650  Al Asalah District, Yanbu balms Conjunction wi...           Yanbu
# 1651               Al Marqab, Riyadh 11564 Saudi Arabia          Riyadh
# 1652             Haram Street, Mecca 24243 Saudi Arabia           Mecca
# 1653   6390 Ibrahim Al Khalil, Mecca 24231 Saudi Arabia           Mecca
# 1654       Al Manakhah, 6666, Medina 42311 Saudi Arabia          Medina
# 1655  King Abdullah Road East of governmental center...           Ha'il
#
#      addressobj/country addressobj/postalcode  \
# 1646       Saudi Arabia                 35514
# 1647       Saudi Arabia                 31311
# ...

# %%
print('Random 10 rows:')
tripadvisor_df.sample(10)
# Out:
# Random 10 rows:
#                                                 address addressobj/city  \
# 1600  Al-Worood Street From King Fahd Street 60, Al ...          Jeddah
# 788   King Saud Rd, Al Mubarraz, Al Ahsa 36422 Saudi...     Al Mubarraz
# 922   Aseer Street, Behind of Venice Mall, Al Khobar...       Al Khobar
# 182          Al Thumama Road, Riyadh 11263 Saudi Arabia          Riyadh
# 11    King Faisal Road, Khamis Mushait 61961 Saudi A...  Khamis Mushait
# 1131  Salah Ad Din Ayyoubi Rd Near the NCB Bank, Riy...          Riyadh
# 154   Ibrahim Al Khalil Ibrahim Al Alkhlil Street - ...           Mecca
# 927   Firas Ibn Al Nuduri Street Al Olaya District, ...       Al Khobar
# 1454         Al Nahda Road, Buraidah 51431 Saudi Arabia        Buraidah
# 694   King Fasial Street Eastern Road, Al Jubail 319...       Al Jubail
#
#      addressobj/country addressobj/postalcode  \
# 1600       Saudi Arabia                 21414
# 788        Saudi Arabia                 36422
# ...

# %% [markdown]
# # Booking Sample

# %%
print('First 10 rows:')
booking_df.head(10)
# Out:
# First 10 rows:
#                                            avatarurl checkindate checkoutdate  \
# 0  https://graph.facebook.com/v2.9/10203533448254...  2023-02-16   2023-02-18
# 1  https://xx.bstatic.com/static/img/review/avata...  2025-01-08   2025-01-09
# 2  https://xx.bstatic.com/static/img/review/avata...  2025-01-01   2025-01-04
# 3  https://xx.bstatic.com/static/img/review/avata...  2025-01-03   2025-01-04
# 4  https://lh4.googleusercontent.com/-FNlr7yiOScc...  2024-12-31   2025-01-03
# 5  https://xx.bstatic.com/static/img/review/avata...  2024-12-31   2025-01-03
# 6  https://xx.bstatic.com/static/img/review/avata...  2024-12-25   2024-12-28
# 7  https://graph.facebook.com/v2.9/49675657732933...  2024-12-21   2024-12-22
# 8  https://xx.bstatic.com/static/img/review/avata...  2024-12-20   2024-12-22
# 9  https://lh3.googleusercontent.com/a/AATXAJyMdD...  2024-12-13   2024-12-14
#
#   countrycode           countryname     customertype guesttypetranslation  \
# ...

# %%
print('Last 10 rows:')
booking_df.tail(10)
# Out:
# Last 10 rows:
#                                              avatarurl checkindate  \
# 160  https://xx.bstatic.com/static/img/review/avata...  2024-10-29
# 161  https://graph.facebook.com/v2.9/69050602062406...  2024-10-15
# 162  https://xx.bstatic.com/static/img/review/avata...  2024-09-27
# 163  https://lh4.googleusercontent.com/-UnlqkRQhfHI...  2024-09-12
# 164  https://graph.facebook.com/v2.9/10156657944168...  2024-09-05
# 165  https://xx.bstatic.com/static/img/review/avata...  2024-09-05
# 166  https://xx.bstatic.com/xdata/images/xphoto/squ...  2024-08-29
# 167  https://xx.bstatic.com/static/img/review/avata...  2024-06-07
# 168  https://xx.bstatic.com/static/img/review/avata...  2024-08-23
# 169  https://xx.bstatic.com/static/img/review/avata...  2024-08-21
#
#     checkoutdate countrycode     countryname      customertype  \
# 160   2024-10-30          hk       Hong Kong           COUPLES
# 161   2024-10-17          sa    Saudi Arabia          FAMILIES
# ...

# %%
print('Random 10 rows:')
booking_df.sample(10)
# Out:
# Random 10 rows:
#                                              avatarurl checkindate  \
# 90   https://xx.bstatic.com/static/img/review/avata...  2024-12-25
# 136  https://lh3.googleusercontent.com/-LETwA0eV6dI...  2024-12-20
# 84   https://lh6.googleusercontent.com/-rkF6Bfpd-RE...  2024-10-30
# 161  https://graph.facebook.com/v2.9/69050602062406...  2024-10-15
# 33   https://xx.bstatic.com/static/img/review/avata...  2024-12-09
# 47   https://xx.bstatic.com/static/img/review/avata...  2024-09-16
# 96   https://graph.facebook.com/v2.9/10155024542172...  2024-11-06
# 17   https://graph.facebook.com/v2.9/27435168958402...  2024-12-30
# 72   https://xx.bstatic.com/xdata/images/xphoto/squ...  2024-12-02
# 89   https://lh3.googleusercontent.com/a-/AOh14Gjxw...  2024-10-17
#
#     checkoutdate countrycode           countryname     customertype  \
# 90    2024-12-30          sa          Saudi Arabia          COUPLES
# 136   2024-12-22          ae  United Arab Emirates         FAMILIES
# ...

# %% [markdown]
# # Ministry of Tourism Samples

# %% [markdown]
# ## 1- Tourism Key Indicators for Inbound and Domestic

# %%
print('First 10 rows:')
KeyIndic_df.head(10)
# Out:
# First 10 rows:
#        Month  Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 0    January                                              2,482
# 1   February                                              2,456
# 2      March                                              2,870
# 3      April                                              2,424
# 4        May                                              1,514
# 5       June                                              2,847
# 6       July                                              1,350
# 7     August                                              2,109
# 8  September                                              2,040
# 9    October                                              2,191
#
#    Overnight Stay\nليالي الإقامة  Tourists Spending\nإنفاق السياح  \
# 0                         35,032                           10,572
# 1                         35,628                           11,705
# ...

# %%
print('Last 10 rows:')
KeyIndic_df.tail(10)
# Out:
# Last 10 rows:
#         Month  \
# 16      April
# 17        May
# 18       June
# 19       July
# 20     August
# 21  September
# 22    October
# 23   November
# 24   December
# 25        NaN
#
#     Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 16                                              6,881
# 17                                              5,003
# 18                                              9,548
# 19                                              8,118
# 20                                              6,986
# 21                                              6,074
# 22                                              6,202
# 23                                              8,220
# 24                                              6,484
# 25                                             81,920
#
#     Overnight Stay\nليالي الإقامة  Tourists Spending\nإنفاق السياح  \
# 16                         38,120                            9,428
# ...

# %%
print('Random 10 rows:')
KeyIndic_df.sample(10)
# Out:
# Random 10 rows:
#         Month  \
# 8   September
# 9     October
# 16      April
# 7      August
# 17        May
# 25        NaN
# 4         May
# 12      Total
# 14   February
# 10   November
#
#     Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 8                                               2,040
# 9                                               2,191
# 16                                              6,881
# 7                                               2,109
# 17                                              5,003
# 25                                             81,920
# 4                                               1,514
# 12                                             27,424
# 14                                              5,608
# 10                                              2,238
#
#     Overnight Stay\nليالي الإقامة  Tourists Spending\nإنفاق السياح  \
# 8                          28,142                            7,735
# ...

# %% [markdown]
# ## 2- Tourists Number Main Purpose for Inbound and Domestic

# %%
print('First 10 rows:')
MainPurpose_df.head(10)
# Out:
# First 10 rows:
#        Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 0    January                       1,035                150
# 1   February                       1,105                144
# 2      March                       1,378                165
# 3      April                       1,005                147
# 4        May                         348                166
# 5       June                       1,715                129
# 6       July                         185                132
# 7     August                         749                146
# 8  September                         861                147
# 9    October                         981                169
#
#    Leisure*\nالترفيه*  Other\n أخرى  \
# 0                 523           164
# 1                 514           157
# 2                 533           146
# 3                 549           122
# 4                 386           101
# 5                 424           101
# ...

# %%
print('Last 10 rows:')
MainPurpose_df.tail(10)
# Out:
# Last 10 rows:
#         Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 16      April                       1,133                613
# 17        May                         526                536
# 18       June                       1,235                786
# 19       July                         753                729
# 20     August                         837                800
# 21  September                         690                667
# 22    October                         707                835
# 23   November                         997                793
# 24   December                         758                720
# 25        NaN                       9,925              8,195
#
#     Leisure*\nالترفيه*  Other\n أخرى  \
# 16               2,523           NaN
# 17               2,246           NaN
# 18               3,887           NaN
# 19               3,689           NaN
# 20               2,836           NaN
# 21               2,473           NaN
# ...

# %%
print('Random 10 rows:')
MainPurpose_df.sample(10)
# Out:
# Random 10 rows:
#         Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 13    January                         658                537
# 15      March                         996                633
# 14   February                         636                546
# 7      August                         749                146
# 19       July                         753                729
# 21  September                         690                667
# 9     October                         981                169
# 3       April                       1,005                147
# 22    October                         707                835
# 4         May                         348                166
#
#     Leisure*\nالترفيه*  Other\n أخرى  \
# 13               3,086           NaN
# 15               2,605           NaN
# 14               2,619           NaN
# 7                  580           127
# 19               3,689           NaN
# 21               2,473           NaN
# ...

# %% [markdown]
# ## 3- Tourists Number Provinces for Inbound and Domestic

# %%
print('First 10 rows:')
TouristNumProv_df.head(10)
# Out:
# First 10 rows:
#       Month                             Indicator     Albaha    Alqassim  \
# 0   January  Tourists Number (Overnight Visitors)        340       9,200
# 1       NaN               Tourists Spending (SAR)  1,478,175  21,402,044
# 2  February  Tourists Number (Overnight Visitors)        NaN       9,589
# 3       NaN               Tourists Spending (SAR)        NaN  29,720,194
# 4     March  Tourists Number (Overnight Visitors)        NaN      17,300
# 5       NaN               Tourists Spending (SAR)        NaN  57,194,374
# 6     April  Tourists Number (Overnight Visitors)        NaN       1,990
# 7       NaN               Tourists Spending (SAR)        NaN   5,241,659
# 8       May  Tourists Number (Overnight Visitors)      1,188       7,621
# 9       NaN               Tourists Spending (SAR)  2,827,554  19,273,936
#
#          Aseer        Eastern         Hail       Jazan        Jouf  \
# 0       12,528        632,931       28,913       2,523      16,537
# ...

# %%
print('Last 10 rows:')
TouristNumProv_df.tail(10)
# Out:
# Last 10 rows:
#         Month                             Indicator         Albaha  \
# 42  September  Tourists Number (Overnight Visitors)         62,547
# 43        NaN               Tourists Spending (SAR)     52,442,868
# 44    October  Tourists Number (Overnight Visitors)         40,069
# 45        NaN               Tourists Spending (SAR)     46,273,685
# 46   November  Tourists Number (Overnight Visitors)         53,722
# 47        NaN               Tourists Spending (SAR)     39,580,899
# 48   December  Tourists Number (Overnight Visitors)         43,725
# 49        NaN               Tourists Spending (SAR)     45,747,471
# 50      Total  Tourists Number (Overnight Visitors)      1,070,829
# 51        NaN               Tourists Spending (SAR)  1,237,245,074
#
#          Alqassim           Aseer         Eastern           Hail  \
# 42        306,215         470,275       1,092,625        141,959
# 43    269,280,242     605,214,901   1,526,308,843    303,571,791
# ...

# %%
print('Random 10 rows:')
TouristNumProv_df.sample(10)
# Out:
# Random 10 rows:
#         Month                             Indicator      Albaha     Alqassim  \
# 6       April  Tourists Number (Overnight Visitors)         NaN        1,990
# 16  September  Tourists Number (Overnight Visitors)       3,031       14,391
# 8         May  Tourists Number (Overnight Visitors)       1,188        7,621
# 11        NaN               Tourists Spending (SAR)         NaN   15,666,851
# 4       March  Tourists Number (Overnight Visitors)         NaN       17,300
# 17        NaN               Tourists Spending (SAR)   7,814,898   31,862,196
# 38       July  Tourists Number (Overnight Visitors)     249,008      384,155
# 46   November  Tourists Number (Overnight Visitors)      53,722      454,746
# 1         NaN               Tourists Spending (SAR)   1,478,175   21,402,044
# 29        NaN               Tourists Spending (SAR)  44,424,048  448,811,010
#
#           Aseer        Eastern         Hail        Jazan         Jouf  \
# ...
