# %%
import tweepy
import pandas as pd

BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAAc0ygEAAAAAQkXlEvP1GjalSvnBzMllKoEnU%2Bo%3DUl9oVFmYEKrMAHSVMXhNdbmK82MkoPWBRdI3OImCiv1VUtOamo'

client = tweepy.Client(bearer_token=BEARER_TOKEN)

query = '#VisitSaudi -is:retweet'
tweets = client.search_recent_tweets(query=query, max_results=100, tweet_fields=['created_at', 'text'])

data = []
for tweet in tweets.data:
    data.append([tweet.created_at, tweet.text])

df = pd.DataFrame(data, columns=['Date', 'Tweet'])
print(df.head())

df.to_csv('tweets.csv', index=False)
print("Tweets saved to tweets.csv")
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-2-fb69da5074f2> in <cell line: 0>()
#       7
#       8 query = '#VisitSaudi -is:retweet'
# ----> 9 tweets = client.search_recent_tweets(query=query, max_results=10, tweet_fields=['created_at', 'text'])
#      10
#      11 data = []
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1264         """
#    1265         params["query"] = query
# -> 1266         return self._make_request(
#    1267             "GET", "/2/tweets/search/recent", params=params,
#    1268             endpoint_parameters=(
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     127         request_params = self._process_params(params, endpoint_parameters)
#     128
# ...

# %% [markdown]
# there is a limit for the free version 100 post only, that is why it will probably show an error becuase i already used my key in pycharm ide when retrieving the data.
