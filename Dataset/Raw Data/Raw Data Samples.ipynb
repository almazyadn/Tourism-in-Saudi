# %%
import pandas as pd
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load datasets
survey_df = pd.read_excel("/content/drive/MyDrive/Raw Data Files/Survey.xlsx")
twitter_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/posts.csv")
tripadvisor_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/tripadvisor-scraper.csv")
booking_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/booking-com-reviews-scraper.csv")
#Ministry of Tourism data sheets
ministryI1_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/I1-Inbound-Tourism-Key-Indicators.csv")
ministryD1_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/D1-Domestic-Tourism-Key-Indicators.csv")
ministryI2_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/I2-Inbound-Tourists-Number-Main-Purpose.csv")
ministryD2_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/D2-Domestic-Tourists-Number-Main-Purpose.csv")
ministryI5_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/I5-Inbound-Tourists-Number-Provinces.csv")
ministryD4_df = pd.read_csv("/content/drive/MyDrive/Raw Data Files/D4-Domestic-Tourists-Number-Provinces.csv")

# %% [markdown]
# # Survey Sample

# %%
print('First 10 rows:')
survey_df.head(10)
# Out:
# First 10 rows:
#                 Timestamp  \
# 0 2025-02-06 16:14:53.594
# 1 2025-02-06 16:19:59.195
# 2 2025-02-06 16:21:46.676
# 3 2025-02-06 16:26:14.395
# 4 2025-02-06 16:27:50.655
# 5 2025-02-06 16:29:04.953
# 6 2025-02-06 16:29:12.680
# 7 2025-02-06 16:34:52.582
# 8 2025-02-06 16:35:11.593
# 9 2025-02-06 16:41:20.095
#
#   0-Which city or destination in Saudi Arabia did you visit the most?   \
# 0                                              شقراء
# 1                                             Dammam
# 2                                             Riyadh
# 3                                             Riyadh
# 4                                             Riyadh
# 5                                             Riyadh
# 6                                             Jeddah
# 7                                             Riyadh
# 8                                             Al-Ula
# 9                                             Riyadh
#
# ...

# %%
print('Last 10 rows:')
survey_df.tail(10)
# Out:
# Last 10 rows:
#                  Timestamp  \
# 49 2025-02-06 19:07:21.696
# 50 2025-02-06 19:41:12.268
# 51 2025-02-06 19:59:10.362
# 52 2025-02-06 21:33:24.201
# 53 2025-02-07 01:32:53.966
# 54 2025-02-07 05:49:51.720
# 55 2025-02-07 11:41:08.410
# 56 2025-02-08 04:19:04.515
# 57 2025-02-08 04:22:32.921
# 58 2025-03-09 18:49:12.267
#
#    0-Which city or destination in Saudi Arabia did you visit the most?   \
# 49                                   Eastern Province
# 50                                             Riyadh
# 51                                             Riyadh
# 52                                             Riyadh
# 53                                             Jeddah
# 54                                             Riyadh
# 55  Al-Taif (almost all my trips were there i am s...
# 56                                             Jeddah
# 57                                             Riyadh
# 58                                             Jeddah
#
# ...

# %%
print('Random 10 rows:')
survey_df.sample(10)
# Out:
# Random 10 rows:
#                  Timestamp  \
# 5  2025-02-06 16:29:04.953
# 28 2025-02-06 18:04:12.130
# 33 2025-02-06 18:20:06.612
# 57 2025-02-08 04:22:32.921
# 6  2025-02-06 16:29:12.680
# 52 2025-02-06 21:33:24.201
# 39 2025-02-06 18:24:11.384
# 26 2025-02-06 17:54:02.283
# 48 2025-02-06 19:05:23.653
# 1  2025-02-06 16:19:59.195
#
#    0-Which city or destination in Saudi Arabia did you visit the most?   \
# 5                                              Riyadh
# 28                                             Riyadh
# 33                                               Neom
# 57                                             Riyadh
# 6                                              Jeddah
# 52                                             Riyadh
# 39                                             Riyadh
# 26                                             Riyadh
# 48                                             Riyadh
# 1                                              Dammam
#
# ...

# %% [markdown]
# # X Sample

# %%
print('First 10 rows:')
twitter_df.head(10)
# Out:
# First 10 rows:
#                 Timestamp  \
# 0 2025-02-06 16:14:53.594
# 1 2025-02-06 16:19:59.195
# 2 2025-02-06 16:21:46.676
# 3 2025-02-06 16:26:14.395
# 4 2025-02-06 16:27:50.655
# 5 2025-02-06 16:29:04.953
# 6 2025-02-06 16:29:12.680
# 7 2025-02-06 16:34:52.582
# 8 2025-02-06 16:35:11.593
# 9 2025-02-06 16:41:20.095
#
#   0-Which city or destination in Saudi Arabia did you visit the most?   \
# 0                                              شقراء
# 1                                             Dammam
# 2                                             Riyadh
# 3                                             Riyadh
# 4                                             Riyadh
# 5                                             Riyadh
# 6                                             Jeddah
# 7                                             Riyadh
# 8                                             Al-Ula
# 9                                             Riyadh
#
# ...

# %%
print('Last 10 rows:')
twitter_df.tail(10)
# Out:
# Last 10 rows:
#                          Date  \
# 43  2025-01-23 11:40:00+00:00
# 44  2025-01-23 09:40:00+00:00
# 45  2025-01-23 09:02:43+00:00
# 46  2025-01-23 07:23:25+00:00
# 47  2025-01-23 06:38:17+00:00
# 48  2025-01-22 22:00:00+00:00
# 49  2025-01-22 18:07:17+00:00
# 50  2025-01-22 18:00:00+00:00
# 51  2025-01-22 16:30:25+00:00
# 52  2025-01-22 14:30:08+00:00
#
#                                                 Tweet
# 43  استعدوا لتجربة استثنائية على ساحل البحر الأحمر...
# 44  استعدوا لتجربة مغامرات الصحراء في "كثبان العرب...
# 45  Visiting Riyadh? The new #Riyadh #Metro is a g...
# 46  جمعنا لكم أفضل الأماكن للإقامة في مكة أثناء ال...
# 47  📷 احجز الآن وابدأ رحلتك الروحانية معنا.\n#فندق...
# 48  عبق الماضي ونبض الحاضر: دليلك لزيارة كنوز #الم...
# 49  ما الأنشطة التي تستمتعون بها وتضفون بها جمالاً...
# 50  جمعنا لكم أفضل الأماكن للإقامة في مكة أثناء ال...
# 51  Calling all thrillseekers! ⚡ #SaudiRedSea is y...
# 52  When was the last time you did something for t...

# %%
print('Random 10 rows:')
twitter_df.sample(10)
# Out:
# Random 10 rows:
#                          Date  \
# 4   2025-01-29 06:19:16+00:00
# 38  2025-01-23 16:18:16+00:00
# 31  2025-01-24 07:37:42+00:00
# 47  2025-01-23 06:38:17+00:00
# 0   2025-01-29 11:57:32+00:00
# 14  2025-01-26 17:48:05+00:00
# 12  2025-01-27 17:00:32+00:00
# 35  2025-01-24 07:03:06+00:00
# 18  2025-01-26 13:30:10+00:00
# 39  2025-01-23 15:30:07+00:00
#
#                                                 Tweet
# 4   خوضوا تجربة جديدة وشيقة وابدأوا رحلتكم في عالم...
# 38  استهلّ يومك بتناول وجبة فطور شهية\nStart your ...
# 31  https://t.co/T2dSCcq1n5\n#عالم_الضيافة #راحة_و...
# 47  📷 احجز الآن وابدأ رحلتك الروحانية معنا.\n#فندق...
# 0   From the moment you arrive at Tulip Inn Al Dar...
# 14  عيش أحلى الأوقات بتجارب سياحية حول المملكة مع ...
# 12  Experience the beauty of AlUla’s Maraya, the w...
# 35  🌟 Scopri il fascino dell’Arabia Saudita! 🌟 Dai...
# 18  When was the last time you did something for t...
# 39  When was the last time you did something for t...

# %% [markdown]
# # TripAdvisor Sample

# %%
print('First 10 rows:')
tripadvisor_df.head(10)
# Out:
# First 10 rows:
#                                              address addressObj/city  \
# 0  Ibrahim Al Khalil Rd Masfelah District, Mecca ...           Mecca
# 1  8792 Al Rayan Unit No. 1 Imam Boukhari Street,...        Buraidah
# 2  Al Urubah Rd Umm Al Hamam Al Gharbi, Riyadh 12...          Riyadh
# 3  Muhammad Zaidan, Al Naeem, Jeddah, Jeddah 2352...          Jeddah
# 4  Al Dalaa Northern 1244 Bldg No 8964, NEOM Comm...         Sharmaa
# 5  Corniche Road Al Shatiea, Jeddah 21411 Saudi A...          Jeddah
# 6           North Hail City Road, Ha'il Saudi Arabia           Ha'il
# 7          King Fahd Road, Dammam 31441 Saudi Arabia          Dammam
# 8  Jarir Street Al Ihsa Interchange, Riyadh 12831...          Riyadh
# 9  Prince Turkey Street 6681 Al Amir Turki, Unit ...       Al Khobar
#
#   addressObj/country addressObj/postalcode  addressObj/state  \
# 0       Saudi Arabia                 24231               NaN
# 1       Saudi Arabia                 52344               NaN
# ...

# %%
print('Last 10 rows:')
tripadvisor_df.tail(10)
# Out:
# Last 10 rows:
#                                                 address addressObj/city  \
# 1646  Al Balad-Madinah Road, Al Jubail 35514 Saudi A...       Al Jubail
# 1647  Al Dawadmi Street, Al Mughrizat District, Riya...          Riyadh
# 1648  Abu Ayyub Al Ansari, Central Area, Medina 4231...          Medina
# 1649  Al Hijra Street Al Missfallah District, Mecca ...           Mecca
# 1650  Al Asalah District, Yanbu balms Conjunction wi...           Yanbu
# 1651               Al Marqab, Riyadh 11564 Saudi Arabia          Riyadh
# 1652             Haram Street, Mecca 24243 Saudi Arabia           Mecca
# 1653   6390 Ibrahim Al Khalil, Mecca 24231 Saudi Arabia           Mecca
# 1654       Al Manakhah, 6666, Medina 42311 Saudi Arabia          Medina
# 1655  King Abdullah Road East of governmental center...           Ha'il
#
#      addressObj/country addressObj/postalcode  addressObj/state  \
# 1646       Saudi Arabia                 35514               NaN
# ...

# %%
print('Random 10 rows:')
tripadvisor_df.sample(10)
# Out:
# Random 10 rows:
#                                                 address addressObj/city  \
# 1117  Riyadh Street Alaziziyah, AlUla 43511 Saudi Ar...           AlUla
# 1514         King Fahad Road, Riyadh 11564 Saudi Arabia          Riyadh
# 915                           Riyadh 13316 Saudi Arabia          Riyadh
# 898   Prince Turki Bin Abdulaziz Street, Al Khobar 5...       Al Khobar
# 989             King Abdullah Road, Shaqra Saudi Arabia          Shaqra
# 910              Qasim Zinah, Jeddah 23434 Saudi Arabia          Jeddah
# 1654       Al Manakhah, 6666, Medina 42311 Saudi Arabia          Medina
# 962                           Sakaka 72345 Saudi Arabia          Sakaka
# 599   Al Mansur Street Jarham district, Mecca 24232 ...           Mecca
# 734   3285 Prince Mohammed Bin Fahd Road, Dammam 324...          Dammam
#
#      addressObj/country addressObj/postalcode  addressObj/state  \
# 1117       Saudi Arabia                 43511               NaN
# ...

# %% [markdown]
# # Booking Sample

# %%
print('First 10 rows:')
booking_df.head(10)
# Out:
# First 10 rows:
#                                            avatarUrl checkinDate checkoutDate  \
# 0  https://graph.facebook.com/v2.9/10203533448254...  2023-02-16   2023-02-18
# 1  https://xx.bstatic.com/static/img/review/avata...  2025-01-08   2025-01-09
# 2  https://xx.bstatic.com/static/img/review/avata...  2025-01-01   2025-01-04
# 3  https://xx.bstatic.com/static/img/review/avata...  2025-01-03   2025-01-04
# 4  https://lh4.googleusercontent.com/-FNlr7yiOScc...  2024-12-31   2025-01-03
# 5  https://xx.bstatic.com/static/img/review/avata...  2024-12-31   2025-01-03
# 6  https://xx.bstatic.com/static/img/review/avata...  2024-12-25   2024-12-28
# 7  https://graph.facebook.com/v2.9/49675657732933...  2024-12-21   2024-12-22
# 8  https://xx.bstatic.com/static/img/review/avata...  2024-12-20   2024-12-22
# 9  https://lh3.googleusercontent.com/a/AATXAJyMdD...  2024-12-13   2024-12-14
#
#   countryCode           countryName     customerType guestTypeTranslation  \
# ...

# %%
print('Last 10 rows:')
booking_df.tail(10)
# Out:
# Last 10 rows:
#                                              avatarUrl checkinDate  \
# 160  https://xx.bstatic.com/static/img/review/avata...  2024-10-29
# 161  https://graph.facebook.com/v2.9/69050602062406...  2024-10-15
# 162  https://xx.bstatic.com/static/img/review/avata...  2024-09-27
# 163  https://lh4.googleusercontent.com/-UnlqkRQhfHI...  2024-09-12
# 164  https://graph.facebook.com/v2.9/10156657944168...  2024-09-05
# 165  https://xx.bstatic.com/static/img/review/avata...  2024-09-05
# 166  https://xx.bstatic.com/xdata/images/xphoto/squ...  2024-08-29
# 167  https://xx.bstatic.com/static/img/review/avata...  2024-06-07
# 168  https://xx.bstatic.com/static/img/review/avata...  2024-08-23
# 169  https://xx.bstatic.com/static/img/review/avata...  2024-08-21
#
#     checkoutDate countryCode     countryName      customerType  \
# 160   2024-10-30          hk       Hong Kong           COUPLES
# 161   2024-10-17          sa    Saudi Arabia          FAMILIES
# ...

# %%
print('Random 10 rows:')
booking_df.sample(10)
# Out:
# Random 10 rows:
#                                              avatarUrl checkinDate  \
# 100  https://xx.bstatic.com/static/img/review/avata...  2024-12-29
# 123  https://graph.facebook.com/v2.9/10238149768982...  2025-01-12
# 55   https://lh5.googleusercontent.com/-jx_95FaAxb0...  2024-05-17
# 39   https://xx.bstatic.com/static/img/review/avata...  2024-12-02
# 23   https://lh3.googleusercontent.com/a-/AOh14GjfG...  2024-11-13
# 149  https://lh6.googleusercontent.com/-JLivnGxE5i4...  2024-10-11
# 90   https://xx.bstatic.com/static/img/review/avata...  2024-12-25
# 46   https://lh3.googleusercontent.com/a/AATXAJxS0m...  2024-09-24
# 26   https://xx.bstatic.com/static/img/review/avata...  2024-12-02
# 134  https://xx.bstatic.com/static/img/review/avata...  2024-12-27
#
#     checkoutDate countryCode           countryName     customerType  \
# 100   2025-01-01          ae  United Arab Emirates         FAMILIES
# 123   2025-01-13          mu             Mauritius         FAMILIES
# ...

# %% [markdown]
# # Ministry of Tourism Samples

# %% [markdown]
# ## 1- Inbound Tourism Key Indicators

# %%
print('First 10 rows:')
ministryI1_df.head(10)
# Out:
# First 10 rows:
#    Unnamed: 0      Month  \
# 0         NaN       Unit
# 1      2021.0    January
# 2         NaN   February
# 3         NaN      March
# 4         NaN      April
# 5         NaN        May
# 6         NaN       June
# 7         NaN       July
# 8         NaN     August
# 9         NaN  September
#
#    Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 0                                             ('000)
# 1                                                233
# 2                                                125
# 3                                                148
# 4                                                176
# 5                                                185
# 6                                                175
# 7                                                231
# 8                                                257
# 9                                                308
#
# ...

# %%
print('Last 10 rows:')
ministryI1_df.tail(10)
# Out:
# Last 10 rows:
#     Unnamed: 0      Month  \
# 30         NaN      April
# 31         NaN        May
# 32         NaN       June
# 33         NaN       July
# 34         NaN     August
# 35         NaN  September
# 36         NaN    October
# 37         NaN   November
# 38         NaN   December
# 39         NaN      Total
#
#     Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 30                                              2,424
# 31                                              1,514
# 32                                              2,847
# 33                                              1,350
# 34                                              2,109
# 35                                              2,040
# 36                                              2,191
# 37                                              2,238
# 38                                              2,903
# 39                                             27,424
#
# ...

# %%
print('Random 10 rows:')
ministryI1_df.sample(10)
# Out:
# Random 10 rows:
#     Unnamed: 0      Month  \
# 32         NaN       June
# 9          NaN  September
# 0          NaN       Unit
# 22         NaN  September
# 34         NaN     August
# 29         NaN      March
# 21         NaN     August
# 27      2023.0    January
# 28         NaN   February
# 8          NaN     August
#
#     Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 32                                              2,847
# 9                                                 308
# 0                                              ('000)
# 22                                              1,539
# 34                                              2,109
# 29                                              2,870
# 21                                              1,311
# 27                                              2,482
# 28                                              2,456
# 8                                                 257
#
# ...

# %% [markdown]
# ## 2- Domestic-Tourism-Key-Indicators

# %%
print('First 10 rows:')
ministryD1_df.head(10)
# Out:
# First 10 rows:
#   Unnamed: 0      Month  \
# 0        NaN       Unit
# 1       2021    January
# 2        NaN   February
# 3        NaN      March
# 4        NaN      April
# 5        NaN        May
# 6        NaN       June
# 7        NaN       July
# 8        NaN     August
# 9        NaN  September
#
#    Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 0                                             ('000)
# 1                                              5,920
# 2                                              4,376
# 3                                              4,408
# 4                                              4,431
# 5                                              6,728
# 6                                              4,166
# 7                                              7,533
# 8                                              5,482
# 9                                              4,185
#
# ...

# %%
print('Last 10 rows:')
ministryD1_df.tail(10)
# Out:
# Last 10 rows:
#    Unnamed: 0      Month  \
# 30        NaN      April
# 31        NaN        May
# 32        NaN       June
# 33        NaN       July
# 34        NaN     August
# 35        NaN  September
# 36        NaN    October
# 37        NaN   November
# 38        NaN   December
# 39      Total        NaN
#
#     Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 30                                              6,881
# 31                                              5,003
# 32                                              9,548
# 33                                              8,118
# 34                                              6,986
# 35                                              6,074
# 36                                              6,202
# 37                                              8,220
# 38                                              6,484
# 39                                             81,920
#
# ...

# %%
print('Random 10 rows:')
ministryD1_df.sample(10)
# Out:
# Random 10 rows:
#    Unnamed: 0      Month  \
# 34        NaN     August
# 5         NaN        May
# 6         NaN       June
# 3         NaN      March
# 37        NaN   November
# 24        NaN   November
# 9         NaN  September
# 1        2021    January
# 27       2023    January
# 26      Total        NaN
#
#     Tourists Number (Overnight Visitors) \nعدد السياح (زوار المبيت)  \
# 34                                              6,986
# 5                                               6,728
# 6                                               4,166
# 3                                               4,408
# 37                                              8,220
# 24                                              7,003
# 9                                               4,185
# 1                                               5,920
# 27                                              6,294
# 26                                             77,837
#
# ...

# %% [markdown]
# ## 3- Inbound-Tourists-Number-Main-Purpose

# %%
print('First 10 rows:')
ministryI2_df.head(10)
# Out:
# First 10 rows:
#    Unnamed: 0      Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 0      2021.0    January                           3                 70
# 1         NaN   February                           3                 51
# 2         NaN      March                           2                 67
# 3         NaN      April                           6                 71
# 4         NaN        May                           7                 64
# 5         NaN       June                           3                 69
# 6         NaN       July                          11                 65
# 7         NaN     August                           5                 81
# 8         NaN  September                          29                 85
# 9         NaN    October                          52                115
#
#    Leisure*\nالترفيه*  Other\n أخرى  \
# 0                   6            22
# 1                   3            17
# 2                   6            24
# ...

# %%
print('Last 10 rows:')
ministryI2_df.tail(10)
# Out:
# Last 10 rows:
#     Unnamed: 0      Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 29         NaN      April                       1,005                147
# 30         NaN        May                         348                166
# 31         NaN       June                       1,715                129
# 32         NaN       July                         185                132
# 33         NaN     August                         749                146
# 34         NaN  September                         861                147
# 35         NaN    October                         981                169
# 36         NaN   November                         991                175
# 37         NaN   December                       1,115                194
# 38         NaN      Total                      11,466              1,865
#
#     Leisure*\nالترفيه*  Other\n أخرى  \
# 29                 549           122
# 30                 386           101
# ...

# %%
print('Random 10 rows:')
ministryI2_df.sample(10)
# Out:
# Random 10 rows:
#     Unnamed: 0      Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 6          NaN       July                          11                 65
# 38         NaN      Total                      11,466              1,865
# 21         NaN  September                         618                140
# 30         NaN        May                         348                166
# 29         NaN      April                       1,005                147
# 37         NaN   December                       1,115                194
# 3          NaN      April                           6                 71
# 7          NaN     August                           5                 81
# 9          NaN    October                          52                115
# 27         NaN   February                       1,105                144
#
#     Leisure*\nالترفيه*  Other\n أخرى  \
# 6                   26            47
# 38               6,246         1,645
# ...

# %% [markdown]
# ## 4- Domestic-Tourists-Number-Main-Purpose

# %%
print('First 10 rows:')
ministryD2_df.head(10)
# Out:
# First 10 rows:
#   Unnamed: 0      Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 0       2021    January                         542                619
# 1        NaN   February                         384                469
# 2        NaN      March                         387                529
# 3        NaN      April                         538                517
# 4        NaN        May                         578                596
# 5        NaN       June                         295                426
# 6        NaN       July                         491                358
# 7        NaN     August                         388                464
# 8        NaN  September                         377                367
# 9        NaN    October                         451                455
#
#    Leisure*\nالترفيه*  Other\nأخرى  \
# 0               1,878          244
# 1               1,202          205
# 2               1,215          159
# ...

# %%
print('Last 10 rows:')
ministryD2_df.tail(10)
# Out:
# Last 10 rows:
#    Unnamed: 0      Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 29        NaN      April                       1,133                613
# 30        NaN        May                         526                536
# 31        NaN       June                       1,235                786
# 32        NaN       July                         753                729
# 33        NaN     August                         837                800
# 34        NaN  September                         690                667
# 35        NaN    October                         707                835
# 36        NaN   November                         997                793
# 37        NaN   December                         758                720
# 38      Total        NaN                       9,925              8,195
#
#     Leisure*\nالترفيه*  Other\nأخرى  \
# 29               2,523          259
# 30               2,246          300
# 31               3,887          389
# ...

# %%
print('Random 10 rows:')
ministryD2_df.sample(10)
# Out:
# Random 10 rows:
#    Unnamed: 0      Month  Religious\nالأغراض الدينية  Business\nالأعمال  \
# 32        NaN       July                         753                729
# 3         NaN      April                         538                517
# 37        NaN   December                         758                720
# 15        NaN      March                         549                283
# 19        NaN       July                         948                500
# 33        NaN     August                         837                800
# 1         NaN   February                         384                469
# 12      Total        NaN                       5,459              5,430
# 34        NaN  September                         690                667
# 35        NaN    October                         707                835
#
#     Leisure*\nالترفيه*  Other\nأخرى  \
# 32               3,689          517
# 3                1,193          300
# 37               3,046          211
# ...

# %% [markdown]
# ## 5- Inbound-Tourists-Number-Provinces

# %%
print('First 10 rows:')
ministryI5_df.head(10)
# Out:
# First 10 rows:
#    Unnamed: 0     Month                             Indicator   Albaha  \
# 0      2021.0   January  Tourists Number (Overnight Visitors)       53
# 1         NaN       NaN               Tourists Spending (SAR)   22,552
# 2         NaN  February  Tourists Number (Overnight Visitors)       27
# 3         NaN       NaN               Tourists Spending (SAR)  114,541
# 4         NaN     March  Tourists Number (Overnight Visitors)       31
# 5         NaN       NaN               Tourists Spending (SAR)   38,707
# 6         NaN     April  Tourists Number (Overnight Visitors)       48
# 7         NaN       NaN               Tourists Spending (SAR)   33,072
# 8         NaN       May  Tourists Number (Overnight Visitors)       20
# 9         NaN       NaN               Tourists Spending (SAR)  126,752
#
#      Alqassim      Aseer      Eastern        Hail       Jazan       Jouf  \
# 0         301      1,339       89,529         156         748      1,778
# ...

# %%
print('Last 10 rows:')
ministryI5_df.tail(10)
# Out:
# Last 10 rows:
#     Unnamed: 0      Month                             Indicator      Albaha  \
# 68         NaN  September  Tourists Number (Overnight Visitors)       3,031
# 69         NaN        NaN               Tourists Spending (SAR)   7,814,898
# 70         NaN    October  Tourists Number (Overnight Visitors)       1,703
# 71         NaN        NaN               Tourists Spending (SAR)   4,564,939
# 72         NaN   November  Tourists Number (Overnight Visitors)         415
# 73         NaN        NaN               Tourists Spending (SAR)     773,543
# 74         NaN   December  Tourists Number (Overnight Visitors)           2
# 75         NaN        NaN               Tourists Spending (SAR)       3,457
# 76         NaN      Total  Tourists Number (Overnight Visitors)      16,257
# 77         NaN        NaN               Tourists Spending (SAR)  43,307,211
#
#        Alqassim        Aseer         Eastern           Hail       Jazan  \
# ...

# %%
print('Random 10 rows:')
ministryI5_df.sample(10)
# Out:
# Random 10 rows:
#     Unnamed: 0      Month                             Indicator   Albaha  \
# 32         NaN      April  Tourists Number (Overnight Visitors)      365
# 52      2023.0    January  Tourists Number (Overnight Visitors)      340
# 12         NaN       July  Tourists Number (Overnight Visitors)      107
# 66         NaN     August  Tourists Number (Overnight Visitors)    8,195
# 20         NaN   November  Tourists Number (Overnight Visitors)       93
# 18         NaN    October  Tourists Number (Overnight Visitors)       78
# 16         NaN  September  Tourists Number (Overnight Visitors)       26
# 62         NaN       June  Tourists Number (Overnight Visitors)      NaN
# 9          NaN        NaN               Tourists Spending (SAR)  126,752
# 39         NaN        NaN               Tourists Spending (SAR)  389,689
#
#      Alqassim      Aseer      Eastern       Hail   Jazan       Jouf  \
# 32      2,411         14      293,341      5,415     NaN      6,255
# ...

# %% [markdown]
# ## 6- Domestic-Tourists-Number-Provinces

# %%
print('First 10 rows:')
ministryD4_df.head(10)
# Out:
# First 10 rows:
#    Unnamed: 0     Month                             Indicator       Albaha  \
# 0      2021.0   January  Tourists Number (Overnight Visitors)       58,295
# 1         NaN       NaN               Tourists Spending (SAR)   75,157,579
# 2         NaN  February  Tourists Number (Overnight Visitors)       34,469
# 3         NaN       NaN               Tourists Spending (SAR)   40,889,285
# 4         NaN     March  Tourists Number (Overnight Visitors)       64,736
# 5         NaN       NaN               Tourists Spending (SAR)   89,759,210
# 6         NaN     April  Tourists Number (Overnight Visitors)       55,486
# 7         NaN       NaN               Tourists Spending (SAR)   58,453,265
# 8         NaN       May  Tourists Number (Overnight Visitors)      158,744
# 9         NaN       NaN               Tourists Spending (SAR)  208,515,699
#
#       Alqassim          Aseer        Eastern         Hail        Jazan  \
# ...

# %%
print('Last 10 rows:')
ministryD4_df.tail(10)
# Out:
# Last 10 rows:
#     Unnamed: 0      Month                             Indicator  \
# 68         NaN  September  Tourists Number (Overnight Visitors)
# 69         NaN        NaN               Tourists Spending (SAR)
# 70         NaN    October  Tourists Number (Overnight Visitors)
# 71         NaN        NaN               Tourists Spending (SAR)
# 72         NaN   November  Tourists Number (Overnight Visitors)
# 73         NaN        NaN               Tourists Spending (SAR)
# 74         NaN   December  Tourists Number (Overnight Visitors)
# 75         NaN        NaN               Tourists Spending (SAR)
# 76         NaN      Total  Tourists Number (Overnight Visitors)
# 77         NaN        NaN               Tourists Spending (SAR)
#
#            Albaha       Alqassim           Aseer         Eastern  \
# 68         62,547        306,215         470,275       1,092,625
# 69     52,442,868    269,280,242     605,214,901   1,526,308,843
# ...

# %%
print('Random 10 rows:')
ministryD4_df.sample(10)
# Out:
# Random 10 rows:
#     Unnamed: 0      Month                             Indicator       Albaha  \
# 26      2022.0    January  Tourists Number (Overnight Visitors)       48,472
# 53         NaN        NaN               Tourists Spending (SAR)   32,259,516
# 64         NaN       July  Tourists Number (Overnight Visitors)      249,008
# 63         NaN        NaN               Tourists Spending (SAR)  333,593,080
# 42         NaN  September  Tourists Number (Overnight Visitors)       34,420
# 55         NaN        NaN               Tourists Spending (SAR)   44,424,048
# 27         NaN        NaN               Tourists Spending (SAR)   59,269,366
# 3          NaN        NaN               Tourists Spending (SAR)   40,889,285
# 18         NaN    October  Tourists Number (Overnight Visitors)       68,976
# 54         NaN   February  Tourists Number (Overnight Visitors)       30,045
#
#        Alqassim          Aseer        Eastern         Hail        Jazan  \
# ...
